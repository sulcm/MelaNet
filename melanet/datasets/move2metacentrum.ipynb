# %%
from metacentrum_utils import copy_data_dir_to_scratch, clear_scratch, ls_scratch, resolve_model_scratch_path

# %%
# dataset_path = "/storage/plzen4-ntis/projects/public/sulcm/SkinCancerDatasets/TestMILK10k"
# dataset_path = "/storage/plzen4-ntis/projects/public/sulcm/SkinCancerDatasets/SpilledMILK10k"
# dataset_path = "/storage/plzen4-ntis/projects/public/sulcm/SkinCancerDatasets/HAM10000"

# dataset_path = "/storage/plzen4-ntis/home/sulcm01/outputs/vit_base/melanet_vit_base_fine_grid-dxjjru4m" # sort of :]

# %%
copy_data_dir_to_scratch(dataset_path)

# %%
ls_scratch()
